# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_generative_ai/blob/main/t81_559_class_04_3_summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-559: Applications of Generative Artificial Intelligence
# **Module 4: LangChain: Chat and Memory**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 4 Material
#
# * Part 4.1: LangChain Conversations [[Video]](https://www.youtube.com/watch?v=-wXT2RlzJec&ab_channel=JeffHeaton) [[Notebook]](t81_559_class_04_1_langchain_chat.ipynb)
# * Part 4.2: Conversation Buffer Window Memory [[Video]](https://www.youtube.com/watch?v=G-l3T1Z9CHc&ab_channel=JeffHeaton) [[Notebook]](t81_559_class_04_2_memory_buffer.ipynb)
# * **Part 4.3: Chat with Summary and Fixed Window** [[Video]](https://www.youtube.com/watch?v=z0iTmoEgn9U&ab_channel=JeffHeaton) [[Notebook]](t81_559_class_04_3_summary.ipynb)
# * Part 4.4: Chat with Persistence, Rollback and Regeneration [[Video]](https://www.youtube.com/watch?v=7QEFjNE6wxs&ab_channel=JeffHeaton) [[Notebook]](t81_559_class_04_4_persistence.ipynb)
# * Part 4.5: Automated Coder Application [[Video]](https://www.youtube.com/watch?v=pHcKXOMDZKU&ab_channel=JeffHeaton) [[Notebook]](t81_559_class_04_5_coder.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running and maps Google Drive if needed.

# %%
import os

try:
    from google.colab import drive, userdata
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# OpenAI Secrets
if COLAB:
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Install needed libraries in CoLab
if COLAB:
    # !pip install langchain langchain_openai
    # !pip install -U langchain-openai
# Out:
# Note: using Google CoLab
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (1.4.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2.32.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.7.34)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (26.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.14.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.14.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.26.0->langchain-openai) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.5.0)

# %% [markdown]
# # 4.3: LangChain Messaging Strategies
#
# This module expands on the earlier `SimpleConversation` wrapper by adding
# pluggable "message strategies" that control how conversation history is stored
# and presented to the LLM. Previously, every conversation simply kept the full
# in-memory history and passed it through as context. That works fine for short
# sessions, but becomes inefficient as chats grow longer.
#
# To address this, we introduce three strategy classes:
#
# 1. PassthroughMessageStrategy
#    - The original behavior. Keeps all messages verbatim and provides the
#      complete history to the model each turn.
#
# 2. FixedWindowMessageStrategy
#    - Maintains only the most recent portion of the conversation. Older
#      messages are dropped from the backing store once a configurable
#      window size is exceeded. This prevents context from growing
#      indefinitely.
#
# 3. SummarizingMessageStrategy
#    - Collapses older messages into a compact, running summary. The summary
#      is maintained with the help of a lightweight LLM call, while the most
#      recent messages are kept verbatim. This lets the model retain important
#      facts and decisions without the cost of replaying the entire chat.
#
# The `SimpleConversation` class now accepts one of these strategies (or a
# factory) when instantiated. This gives you control over how history is
# managed—whether you want full fidelity, bounded context, or long-term memory
# via summarization, while keeping the same simple interface for sending and
# displaying chat turns.
#
# ### BaseMessageStrategy
#
# `BaseMessageStrategy` is the common wrapper class that all message strategies
# inherit from. Its purpose is to provide a consistent interface for adding,
# clearing, and retrieving chat messages, while delegating actual storage to an
# `InMemoryChatMessageHistory` instance. By default it simply passes messages
# through unchanged, but subclasses override how the `messages` property is
# exposed to the model—such as trimming to a fixed window or replacing older
# content with a running summary. This design lets `SimpleConversation` plug in
# different strategies seamlessly, without having to know the details of how
# history is

# %%
from __future__ import annotations
from typing import Optional, List, Dict, Any, Callable, Literal
from uuid import uuid4

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage, BaseMessage
from IPython.display import display_markdown

class BaseMessageStrategy:
    def __init__(self):
        self._backing = InMemoryChatMessageHistory()

    # Required by RunnableWithMessageHistory / callbacks
    def add_user_message(self, message: str) -> None:
        self._backing.add_user_message(message)

    def add_ai_message(self, message: str) -> None:
        self._backing.add_ai_message(message)

    def add_message(self, message: BaseMessage) -> None:
        self._backing.add_message(message)

    def add_messages(self, messages: List[BaseMessage]) -> None:
        self._backing.add_messages(messages)

    def clear(self) -> None:
        self._backing.clear()

    @property
    def backing_messages(self) -> List[BaseMessage]:
        return self._backing.messages

    @property
    def messages(self) -> List[BaseMessage]:
        return list(self._backing.messages)

    # Optional: delegate any other unknown attrs to the backing object
    def __getattr__(self, name):
        return getattr(self._backing, name)

# %% [markdown]
# `PassthroughMessageStrategy` is the simplest strategy implementation. It
# inherits from `BaseMessageStrategy` and provides the full, unmodified chat
# history to the model each turn. Nothing is trimmed, summarized, or filtered—
# the conversation grows indefinitely as more messages are added. This is the
# baseline strategy and represents the original behavior of
# `SimpleConversation` before windowing or summarization were introduced.

# %%
class PassthroughMessageStrategy(BaseMessageStrategy):
    """
    No trimming or summarization. Returns the full history.
    """
    pass

# %% [markdown]
# ### FixedWindowMessageStrategy
#
# `FixedWindowMessageStrategy` enforces a sliding window over the conversation
# so that only the most recent portion of the chat is preserved and passed to
# the model. Older messages beyond this limit are discarded from the backing
# store. This keeps the prompt size under control while still giving the model
# recent context.
#
# Parameters
# ----------
# window : int
#     The maximum number of messages (or turns, depending on implementation)
#     to retain. Once this limit is exceeded, the oldest messages are dropped.
# keep_system_first : bool, default=True
#     If True, the very first system message (e.g., your system prompt) is
#     always preserved, even if the rest of the history is trimmed.
#
# ```
# # Keep only the last 12 messages, always pinning the system prompt
# strategy = FixedWindowMessageStrategy(window=12, keep_system_first=True)
# conv = SimpleConversation(strategy=strategy)
# conv.chat("Hello!")
# ```

# %% [markdown]
# ### FixedWindowMessageStrategy
#
# `SummarizingMessageStrategy` maintains long-running conversations by
# collapsing older exchanges into a concise summary while keeping the most
# recent turns verbatim. This allows the model to retain awareness of key facts
# and decisions without the cost of replaying the entire history.
#
# **Parameters**
#
# summarizer_llm : ChatOpenAI, optional
#     The LLM used to generate summaries. If not provided, defaults to a
#     lightweight GPT-5 mini model with low temperature.
# trigger_len : int, default=20
#     The minimum number of unsummarized messages required before a summary
#     pass is triggered.
# keep_last : int, default=10
#     The number of most recent messages to always preserve verbatim in
#     addition to the running summary.
# max_summary_chars : int, default=1200
#     A soft limit on the length of the summary text.
# system_prefix : str, default="Running summary"
#     A label prepended to the summary when it is injected as a system
#     message.
#
# **Example**
#
# ```
# # Collapse older content but keep the last 10 messages
# strategy = SummarizingMessageStrategy(keep_last=10, trigger_len=20)
# conv = SimpleConversation(strategy=strategy)
# conv.chat("Let's start a long discussion...")
# ```

# %%
from typing import List
from langchain_core.messages import BaseMessage, SystemMessage, HumanMessage, AIMessage

class FixedWindowMessageStrategy(BaseMessageStrategy):
    """
    Enforces a hard cap of `window` messages in the backing store.
    Optionally keeps the very first System message pinned.
    """
    def __init__(self, window: int = 12, keep_system_first: bool = True):
        super().__init__()
        assert window > 0
        self.window = window
        self.keep_system_first = keep_system_first

    # ---- write-path enforcement ----
    def _trim_in_place(self) -> None:
        msgs = self._backing.messages
        if not msgs:
            return

        first_sys = msgs[0] if self.keep_system_first and isinstance(msgs[0], SystemMessage) else None
        body = msgs[1:] if first_sys else msgs

        # keep only last `window` of the body
        if len(body) > self.window:
            body[:] = body[-self.window:]

        # write back
        if first_sys:
            msgs[:] = [first_sys] + body
        else:
            msgs[:] = body

    def add_user_message(self, message: str) -> None:
        super().add_user_message(message)
        self._trim_in_place()

    def add_ai_message(self, message: str) -> None:
        super().add_ai_message(message)
        self._trim_in_place()

    def add_message(self, message: BaseMessage) -> None:
        super().add_message(message)
        self._trim_in_place()

    def add_messages(self, messages: List[BaseMessage]) -> None:
        super().add_messages(messages)
        self._trim_in_place()

    # read-path (still returns whatever is in backing)
    @property
    def messages(self) -> List[BaseMessage]:
        return self._backing.messages

# %% [markdown]
# ### SummarizingMessageStrategy
#
# `SummarizingMessageStrategy` is designed for long conversations where keeping
# every individual message would quickly exceed the model’s context window. It
# retains the most recent `keep_last` messages verbatim, while older messages
# are periodically collapsed into a compact running summary once the number of
# unsummarized messages passes `trigger_len`. The summary itself is generated by
# a lightweight LLM (`summarizer_llm`) and injected back into the conversation
# as a system message so that the model still has access to important facts,
# decisions, and constraints. Parameters like `max_summary_chars` and
# `system_prefix` allow you to control the size and labeling of the summary.
# This strategy is useful when you want the model to remember key details from
# earlier parts of a discussion without carrying the full message history
# forward.

# %%
class SummarizingMessageStrategy(BaseMessageStrategy):
    """
    Maintains a running summary of older turns and keeps the recent tail verbatim.
    When `trigger_len` is exceeded, everything except the last `keep_last` messages
    is summarized via a compact LLM call to `summarizer_llm`.

    The model receives:
      [SystemMessage("Running summary: ..."), <last keep_last messages...>]
    """
    def __init__(
        self,
        summarizer_llm: Optional[ChatOpenAI] = None,
        trigger_len: int = 20,
        keep_last: int = 10,
        max_summary_chars: int = 1200,
        system_prefix: str = "Running summary"
    ):
        super().__init__()
        assert trigger_len > 0 and keep_last > 0, "trigger_len and keep_last must be positive"
        self.summarizer_llm = summarizer_llm or ChatOpenAI(model="gpt-5-mini", temperature=0.0)
        self.trigger_len = trigger_len
        self.keep_last = keep_last
        self.max_summary_chars = max_summary_chars
        self.system_prefix = system_prefix
        self._summary_text: Optional[str] = None
        self._last_summarized_idx: int = 0  # index in backing messages up to which we summarized

    def _need_summarize(self) -> bool:
        return len(self.backing_messages) - self._last_summarized_idx > max(self.keep_last, self.trigger_len)

    def _build_summarization_input(self) -> List[BaseMessage]:
        msgs = self.backing_messages
        head = msgs[: max(0, len(msgs) - self.keep_last)]
        # If we already have a summary, include it as context
        prompt_msgs: List[BaseMessage] = []
        if self._summary_text:
            prompt_msgs.append(SystemMessage(content=f"{self.system_prefix} so far:\n{self._summary_text}"))
        # Add the head to be collapsed
        prompt_msgs.extend(head[self._last_summarized_idx :])
        return prompt_msgs

    def _summarize_now(self) -> None:
        # Compose a tight prompt for the summarizer model
        to_collapse = self._build_summarization_input()
        if not to_collapse:
            return
        # Summarizer prompt
        prompt = [
            SystemMessage(content=(
                "You are a terse assistant that compresses chat histories into factual, "
                "actionable bullet summaries without losing decisions or instructions."
            )),
            HumanMessage(content=(
                "Summarize the following conversation context into 5–10 compact bullets. "
                "Keep entities, tasks, decisions, constraints, and important examples. "
                f"Limit to ~{self.max_summary_chars} characters.\n\n"
                "=== BEGIN CONTEXT ==="
            ))
        ]
        prompt.extend(to_collapse)
        prompt.append(HumanMessage(content="=== END CONTEXT ===\n\nReturn only the bullets."))

        summary = self.summarizer_llm.invoke(prompt)
        new_summary = summary.content.strip()

        # Merge summaries if we already had one
        if self._summary_text:
            # Briefly re-summarize the combined text to keep it tight
            merge_prompt = [
                SystemMessage(content="Condense two bullet lists into one concise list without redundancy."),
                HumanMessage(content=f"List A:\n{self._summary_text}\n\nList B:\n{new_summary}\n\nReturn a single concise list.")
            ]
            merged = self.summarizer_llm.invoke(merge_prompt)
            self._summary_text = merged.content.strip()
        else:
            self._summary_text = new_summary

        # We have summarized all messages up to the current head
        self._last_summarized_idx = max(0, len(self.backing_messages) - self.keep_last)

    @property
    def messages(self) -> List[BaseMessage]:
        # Summarize if needed
        if self._need_summarize():
            self._summarize_now()

        tail = self.backing_messages[-self.keep_last:] if self.keep_last > 0 else []
        if self._summary_text:
            return [SystemMessage(content=f"{self.system_prefix}:\n{self._summary_text}")] + list(tail)
        return list(tail)

    def get_summary_text(self) -> Optional[str]:
        """Return the current running summary, summarizing first if needed."""
        if self._need_summarize():
            self._summarize_now()
        return self._summary_text

# %% [markdown]
# `SimpleConversation` is the main wrapper class for running LangChain-based
# chat sessions. In the original version, it always used a plain in-memory
# message history with no special handling, so every message was kept and
# passed through to the model. In this enhanced version, the class supports
# pluggable *message strategies* that define how the conversation history is
# managed. You can now choose between three built-in strategies:
#
# - `PassthroughMessageStrategy`: the original behavior, keeps the entire
#   history intact with no trimming or summarization.
# - `FixedWindowMessageStrategy`: enforces a sliding window so only the most
#   recent N messages (optionally pinning the first system prompt) are retained.
# - `SummarizingMessageStrategy`: collapses older messages into a compact,
#   running summary while preserving a configurable number of the most recent
#   turns verbatim.
#
# This enhancement lets you control how the conversation grows: either unlimited,
# bounded to a fixed window, or long-term via summarization. The external
# interface of `SimpleConversation` remains the same (`chat`, `invoke`,
# `print_history`, etc.), so you can swap strategies without changing any client
# code.

# %%
StrategyName = Literal["passthrough", "fixed", "summary"]

def _strategy_from_name(name: StrategyName, **kwargs) -> BaseMessageStrategy:
    if name == "passthrough":
        return PassthroughMessageStrategy()
    if name == "fixed":
        return FixedWindowMessageStrategy(**kwargs)
    if name == "summary":
        return SummarizingMessageStrategy(**kwargs)
    raise ValueError(f"Unknown strategy '{name}'")


class SimpleConversation:
    """
    Self-contained conversation wrapper with pluggable message strategies:
      - Create with:
          conv = SimpleConversation(strategy_name="fixed", strategy_kwargs={"window": 14})
        or:
          conv = SimpleConversation(strategy=SummarizingMessageStrategy(keep_last=12))
      - conv.chat("...") to run and display
      - conv.print_history() to dump the backing history
      - conv.to_dicts() to get [{'role': ..., 'content': ...}, ...] from backing
      - conv.clear_history() to reset
    """

    def __init__(
        self,
        model: str = "gpt-5-mini",
        system_prompt: str = "You are a helpful assistant.",
        temperature: float = 0.3,
        session_id: Optional[str] = None,
        # Strategy selection
        strategy: Optional[BaseMessageStrategy] = None,
        strategy_name: StrategyName = "passthrough",
        strategy_kwargs: Optional[Dict[str, Any]] = None,
        # Optional: provide a custom factory if you manage sessions externally
        strategy_factory: Optional[Callable[[], BaseMessageStrategy]] = None,
    ):
        # Prompt with explicit history placeholder
        prompt = ChatPromptTemplate.from_messages([
            ("system", system_prompt.strip()),
            MessagesPlaceholder(variable_name="history"),
            ("human", "{input}")
        ])

        llm = ChatOpenAI(model=model, temperature=temperature)

        # Per-session strategy store
        self._strategy_store: Dict[str, BaseMessageStrategy] = {}

        # Build a factory that creates a fresh strategy per session
        if strategy_factory is not None:
            factory = strategy_factory
        elif strategy is not None:
            # Use the provided instance for all sessions in this object
            factory = lambda: strategy
        else:
            kwargs = strategy_kwargs or {}
            factory = lambda: _strategy_from_name(strategy_name, **kwargs)

        def _history_for_session(sid: str) -> BaseMessageStrategy:
            return self._strategy_store.setdefault(sid, factory())

        # Runnable that pulls history from the strategy instance
        self._runnable = RunnableWithMessageHistory(
            prompt | llm,
            _history_for_session,
            input_messages_key="input",
            history_messages_key="history",
        )

        self._session_id = session_id or str(uuid4())

    def invoke(self, prompt: str):
        return self._runnable.invoke(
            {"input": prompt},
            config={"configurable": {"session_id": self._session_id}},
        )

    def chat(self, prompt: str):
        display_markdown("**Human:** ", raw=True)
        display_markdown(prompt, raw=True)
        output = self.invoke(prompt)
        display_markdown(f"**AI:** ", raw=True)
        display_markdown(output.content, raw=True)

    # Convenience accessors operate on the backing history, not the policy view
    def _strategy_obj(self) -> BaseMessageStrategy:
        return self._strategy_store.setdefault(self._session_id, PassthroughMessageStrategy())

    def get_history(self) -> List[BaseMessage]:
        """Full backing history objects, not policy-trimmed view."""
        return self._strategy_obj().backing_messages

    def to_dicts(self) -> List[Dict[str, Any]]:
        return [{"role": m.type, "content": m.content} for m in self.get_history()]

    def print_history(self):
        history = self.get_history()
        if not history:
            print("(no history)")
            return
        for msg in history:
            role = msg.type.capitalize()
            print(f"{role}: {msg.content}")

    def clear_history(self):
        self._strategy_store[self._session_id] = type(self._strategy_obj())()  # new fresh instance

    @property
    def session_id(self) -> str:
        return self._session_id

# %% [markdown]
# ### Examples
#
# At its simplest, `SimpleConversation` works like a basic chatbot: every message
# is stored in memory and sent back to the model each turn. There is no windowing
# or summarization in this mode, so the conversation grows indefinitely. If the
# history becomes too large for the model’s context, LangChain will not trim it
# and an error is likely to occur.

# %%
conv = SimpleConversation()

conv.chat("Hello I am Fiona")
conv.chat("Who am I")
# Out:
# /tmp/ipykernel_1675/925226036.py:1: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   conv = SimpleConversation()
# **Human:**
# Hello I am Fiona
# **AI:**
# Hi Fiona — nice to meet you! How can I help you today?
# **Human:**
# Who am I
# **AI:**
# You told me your name is Fiona — that's the only fact I know about you so far. I don't have access to any other personal information unless you share it.
#
# Do you mean:
# - Are you asking whether your name is Fiona, or
# - Are you asking a deeper question about your identity (values, roles, purpose)?
#
# If you want to explore "Who am I?" more deeply, here are a few short prompts to get started — pick one and I can help you work through it:
# 1. List three roles you play (e.g., friend, student, parent) and what each means to you.
# 2. Name three values that matter most to you and why.
# 3. Describe a time you felt most like yourself. What were you doing?
# 4. What are your strengths and one skill you'd like to improve?
# 5. What do you want people to remember about you?
# 6. If you could try a new identity/role for a month, what would it be and why?
#
# Which direction would you like to go?

# %% [markdown]
# ### Testing Chat History Overflow
#
# `test_overflow` stress-tests history handling by stuffing the chat with filler
# messages (random dates) after teaching two important facts: the user's name and
# favorite color. Run it once with a buffered strategy (Passthrough or FixedWindow)
# and once with SummarizingMessageStrategy. The buffered approach is prone to
# forget early facts once the window rolls or the context gets large, while the
# summary approach periodically compresses older turns into a compact system note,
# so it is more likely to retain key details like name and favorite color.

# %%
import random
from datetime import datetime, timedelta

def test_overflow(c):
  c.chat("Okay, then let me introduce myself, my name is Fiona")
  c.chat("You have ONE JOB! Remember that my favorite color is blue.")
  c.chat("Do you remember my name?")
  c.chat("Do you remember my favorite color?")

  # Generate random dates from the last 20 years
  today = datetime.today()
  days_in_20_years = 20 * 365  # rough approximation, fine for demo
  for i in range(20):
      random_days = random.randint(0, days_in_20_years)
      random_date = today - timedelta(days=random_days)
      formatted_date = random_date.strftime("%B %d, %Y")
      c.chat(f"Please remember this date #{i}: {formatted_date}. Just tell me OK if you got it.")

  c.chat("Do you remember my name?")
  c.chat("Do you remember my favorite color?")

# %% [markdown]
# Now we can run `test_overflow` using the fixed-window strategy. In this mode,
# the conversation keeps only the most recent N messages and discards everything
# older. This prevents the context from growing too large, but it also means that
# earlier facts—like the user’s name or favorite color—quickly fall out of memory.
# As a result, when asked again at the end, the chatbot is likely to forget these
# details.

# %%
conv_fixed = SimpleConversation(strategy_name="fixed", strategy_kwargs={"window": 14})

test_overflow(conv_fixed)
# Out:
# /tmp/ipykernel_1675/2065539813.py:1: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   conv_fixed = SimpleConversation(strategy_name="fixed", strategy_kwargs={"window": 14})
# **Human:**
# Okay, then let me introduce myself, my name is Fiona
# **AI:**
# Nice to meet you, Fiona — I'm ChatGPT. How can I help you today? For example, I can answer questions, help write or edit text, brainstorm ideas, debug code, plan trips or projects, tutor, and more.
# **Human:**
# You have ONE JOB! Remember that my favorite color is blue.
# **AI:**
# Understood — your favorite color is blue. Consider it remembered for this conversation.
#
# If you want me to keep it across future chats, I can save it to your profile/memory (would you like that?). If you ever change your mind, just tell me.
# **Human:**
# Do you remember my name?
# **AI:**
# Yes — your name is Fiona, and your favorite color is blue. Would you like me to save that so I remember it in future chats?
# **Human:**
# Do you remember my favorite color?
# **AI:**
# Yes — your favorite color is blue. Would you like me to save that so I remember it in future chats?
# **Human:**
# Please remember this date #0: March 23, 2015. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #1: December 28, 2020. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #2: April 07, 2021. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #3: July 20, 2012. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #4: September 24, 2024. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #5: August 19, 2011. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #6: January 10, 2007. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #7: July 19, 2016. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #8: August 07, 2021. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #9: November 15, 2006. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #10: August 24, 2024. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #11: May 16, 2012. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #12: December 12, 2015. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #13: June 01, 2009. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #14: January 11, 2021. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #15: December 22, 2006. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #16: July 30, 2012. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #17: June 02, 2015. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #18: November 14, 2006. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #19: August 11, 2009. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Do you remember my name?
# **AI:**
# I don't — you haven't told me your name. If you'd like, tell me now and I can remember it for the rest of this conversation. If you want me to save it as a longer-term memory for future chats, tell me and I'll ask for permission to store it.
# **Human:**
# Do you remember my favorite color?
# **AI:**
# I don't — you haven't told me your favorite color. Tell me now and I'll remember it for the rest of this conversation. If you want me to save it for future chats, say so and I'll ask to store it as a memory.

# %% [markdown]
# We can now display the history.

# %%
conv_fixed.get_history()
# Out:
# [HumanMessage(content='Please remember this date #15: December 22, 2006. Just tell me OK if you got it.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='OK', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 138, 'prompt_tokens': 285, 'total_tokens': 423, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dhe7Wh9s4MzgVezs0QD4rJOMyiLtf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e463a-796c-7b63-b654-a72cef915f3e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 285, 'output_tokens': 138, 'total_tokens': 423, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#  HumanMessage(content='Please remember this date #16: July 30, 2012. Just tell me OK if you got it.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='OK', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 138, 'prompt_tokens': 285, 'total_tokens': 423, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dhe7ZlarD1yrmIxn4W2Gyob7bBbup', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e463a-8588-7360-aedd-1d8f37783db2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 285, 'output_tokens': 138, 'total_tokens': 423, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#  HumanMessage(content='Please remember this date #17: June 02, 2015. Just tell me OK if you got it.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='OK', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 285, 'total_tokens': 359, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dhe7c4NtLWGErYzqnE45SXhlbUMzh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e463a-9345-7bf3-8dce-f5553ded32ca-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 285, 'output_tokens': 74, 'total_tokens': 359, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#  HumanMessage(content='Please remember this date #18: November 14, 2006. Just tell me OK if you got it.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='OK', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 138, 'prompt_tokens': 285, 'total_tokens': 423, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dhe7ftHmRHxUukKU5ihhlOpTLEWhX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e463a-9cfc-71d1-adba-27a14e5ac2ef-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 285, 'output_tokens': 138, 'total_tokens': 423, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#  HumanMessage(content='Please remember this date #19: August 11, 2009. Just tell me OK if you got it.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='OK', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 202, 'prompt_tokens': 285, 'total_tokens': 487, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dhe7iI3dUoToqlK2cin1o4noJIGoW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e463a-aac5-7982-8f0c-0722d41b462c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 285, 'output_tokens': 202, 'total_tokens': 487, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#  HumanMessage(content='Do you remember my name?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="I don't — you haven't told me your name. If you'd like, tell me now and I can remember it for the rest of this conversation. If you want me to save it as a longer-term memory for future chats, tell me and I'll ask for permission to store it.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 578, 'prompt_tokens': 267, 'total_tokens': 845, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dhe7maiAoU2v0XDXmYCCePsnLHRKl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e463a-b8c8-7f33-9acf-5570812aa0d8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 267, 'output_tokens': 578, 'total_tokens': 845, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#  HumanMessage(content='Do you remember my favorite color?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="I don't — you haven't told me your favorite color. Tell me now and I'll remember it for the rest of this conversation. If you want me to save it for future chats, say so and I'll ask to store it as a memory.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 633, 'prompt_tokens': 305, 'total_tokens': 938, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dhe7uceW3OlYRHy1atxwfm0wK2P0X', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e463a-da72-7b33-9504-20ab633e1111-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 305, 'output_tokens': 633, 'total_tokens': 938, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]

# %% [markdown]
# Next we test the summarizing strategy and see that the important information is remembered.

# %%
## keep_last=8, trigger_len=8 may lose information because summarization is triggered too frequently.
strategy=SummarizingMessageStrategy(keep_last=8, trigger_len=8)
# strategy=SummarizingMessageStrategy(keep_last=8, trigger_len=16)
conv_sum = SimpleConversation(strategy=strategy)

test_overflow(conv_sum)
# Out:
# /tmp/ipykernel_1675/1967775368.py:2: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   conv_sum = SimpleConversation(strategy=strategy)
# **Human:**
# Okay, then let me introduce myself, my name is Fiona
# **AI:**
# Nice to meet you, Fiona — I’m ChatGPT. How can I help today? If you like, tell me how you’d prefer to be addressed (any nickname or pronouns) and what you’d like to work on: questions, writing/editing, brainstorming, planning, coding, learning, or something else.
# **Human:**
# You have ONE JOB! Remember that my favorite color is blue.
# **AI:**
# Got it — one job accepted. Your favorite color is blue. I’ll remember that for this conversation.
#
# Would you like me to:
# - use blue-themed examples/formatting when relevant, or
# - remember it across future chats (I can save it as a preference if you want)?
# **Human:**
# Do you remember my name?
# **AI:**
# Yes — your name is Fiona. Would you like me to use that going forward in this conversation (or save it for future chats)?
# **Human:**
# Do you remember my favorite color?
# **AI:**
# Yes — your favorite color is blue. I’m remembering it for this conversation. Would you like me to save it as a preference for future chats too?
# **Human:**
# Please remember this date #0: September 05, 2020. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #1: September 16, 2007. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #2: August 30, 2022. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #3: March 25, 2010. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #4: March 22, 2026. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #5: July 10, 2021. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #6: March 21, 2016. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #7: June 16, 2023. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #8: July 09, 2013. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #9: April 30, 2011. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #10: March 14, 2019. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #11: July 18, 2022. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #12: December 15, 2013. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #13: July 27, 2006. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #14: August 08, 2011. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #15: August 28, 2011. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #16: February 13, 2010. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #17: January 09, 2016. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #18: April 08, 2021. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Please remember this date #19: February 23, 2009. Just tell me OK if you got it.
# **AI:**
# OK
# **Human:**
# Do you remember my name?
# **AI:**
# I don't have a name saved yet. I have "Fiona" pending confirmation — would you like me to save that as your name? If so, any preferred pronouns to save too?
# **Human:**
# Do you remember my favorite color?
# **AI:**
# I don't have a favorite color saved yet. I have "blue" pending confirmation — would you like me to save that as your favorite color? Reply "Yes" to save it or tell me a different color.

# %% [markdown]
# We can view the internal summary that the object keeps.

# %%
strategy.get_summary_text()
# Out:
# '- Participants and state: Fiona (user) and assistant; assistant accepted directive "You have ONE JOB!" and is standing by to perform that single specified task.  \n- Memory log (saved): #0–#13 previously; #14 — Aug 08, 2011; #15 — Aug 28, 2011; #16 — Feb 13, 2010; #17 — Jan 09, 2016 (just saved; assistant: OK).  \n- Pending memory saves (awaiting user confirmation): name "Fiona"; favorite color "blue."  \n- Recent interactions: user asked to remember dates #9–#13 (assistant acknowledged); assistant saved #14–#17.  \n- Outstanding user inputs/decisions: specify the single job/task; provide preferred name and pronouns; confirm whether to save/apply "Fiona" and "blue."  \n- Offered help categories (available once task specified): questions, writing/editing, brainstorming, planning, coding, learning, other.  \n- Next action required: user to supply the single-task instruction and confirm memory preferences.'
