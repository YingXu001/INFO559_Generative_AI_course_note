# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_generative_ai/blob/main/t81_559_class_03_3_text_summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-559: Applications of Generative Artificial Intelligence
# **Module 3: Large Language Models**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 3 Material
#
# * Part 3.1: Foundation Models [[Video]](https://www.youtube.com/watch?v=Gb0tk5qq1fA) [[Notebook]](t81_559_class_03_1_llm.ipynb)
# * Part 3.2: Text Generation [[Video]](https://www.youtube.com/watch?v=lB97Lqt7q58) [[Notebook]](t81_559_class_03_2_text_gen.ipynb)
# * **Part 3.3: Text Summarization** [[Video]](https://www.youtube.com/watch?v=3MoIUXE2eEU) [[Notebook]](t81_559_class_03_3_text_summary.ipynb)
# * Part 3.4: Text Classification [[Video]](https://www.youtube.com/watch?v=2VpOwFIGmA8) [[Notebook]](t81_559_class_03_4_classification.ipynb)
# * Part 3.5: LLM Writes a Book [[Video]](https://www.youtube.com/watch?v=iU40Rttlb_Q) [[Notebook]](t81_559_class_03_5_book.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running and maps Google Drive if needed.

# %%
import os

try:
    from google.colab import drive, userdata
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# OpenAI Secrets
if COLAB:
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Install needed libraries in CoLab
if COLAB:
    # !pip install langchain langchain_openai pypdf langchain_community
# Out:
# Note: using Google CoLab
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.15)
# Collecting langchain_openai
#   Downloading langchain_openai-1.2.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting pypdf
#   Downloading pypdf-6.11.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.3.1)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.1.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Downloading langchain_core-1.3.3-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (2.32.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (0.12.0)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.7-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.49)
# Collecting requests<3.0.0,>=2.32.5 (from langchain_community)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.13.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (9.1.4)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.14.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.7.34)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.23.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Collecting langchain-protocol>=0.0.10 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading langchain_protocol-0.0.15-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (0.14.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.4.22)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_openai-1.2.1-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 7.1 MB/s eta 0:00:00
# Downloading pypdf-6.11.0-py3-none-any.whl (338 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.8/338.8 kB 23.9 MB/s eta 0:00:00
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 65.7 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_classic-1.0.7-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.7 MB/s eta 0:00:00
# Downloading langchain_core-1.3.3-py3-none-any.whl (543 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.9/543.9 kB 28.5 MB/s eta 0:00:00
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.1 MB/s eta 0:00:00
# Downloading langchain_protocol-0.0.15-py3-none-any.whl (7.0 kB)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.2 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: requests, pypdf, mypy-extensions, marshmallow, langchain-protocol, typing-inspect, dataclasses-json, langchain-core, langchain-text-splitters, langchain_openai, langchain-classic, langchain_community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.3.1
#     Uninstalling langchain-core-1.3.1:
#       Successfully uninstalled langchain-core-1.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.33.1 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 langchain-classic-1.0.7 langchain-core-1.3.3 langchain-protocol-0.0.15 langchain-text-splitters-1.1.2 langchain_community-0.4.1 langchain_openai-1.2.1 marshmallow-3.26.2 mypy-extensions-1.1.0 pypdf-6.11.0 requests-2.33.1 typing-inspect-0.9.0

# %% [markdown]
# # 3.3: Text Summarization
#
# Large Language Models (LLMs) like GPT-4 can be utilized to summarize text by extracting key information and presenting it in a concise format. They work by understanding the context and semantic relationships within the original text and then generating a shorter version that retains the essential messages. This process involves natural language understanding and generation capabilities, allowing LLMs to interpret various types of texts, from technical articles to narratives, and produce summaries that are coherent and relevant. The ability to customize the length and focus of the summary based on user preferences makes LLMs particularly effective for digesting large volumes of information quickly and efficiently.
#
# ## Summarize Single PDF
#
# We will begin by seeing how to summarize a single PDF. LangChang loads document types, such as PDFs, using a document loader. There are document loaders for various data types. The following code summarizes a single PDF using a generic summarization system prompt.

# %%
# from langchain.chains.summarize import load_summarize_chain
from langchain_classic.chains.summarize import load_summarize_chain
# from langchain.document_loaders import PyPDFLoader, TextLoader
from langchain_community.document_loaders import PyPDFLoader, TextLoader
# from langchain import OpenAI, PromptTemplate
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from IPython.display import display_markdown

MODEL = 'gpt-5-mini'

llm = ChatOpenAI(
        model=MODEL,
        temperature=0.2,
        n=1
    )

# %% [markdown]
# The following code snippet demonstrates how to use a specific 'load_summarize_chain' function to set up a summarization process using a Large Language Model (LLM) with a "map_reduce" chain type. It starts by loading a PDF from the given URL ("https://arxiv.org/pdf/1706.03762") using the 'PyPDFLoader'. The loaded document is then split into manageable parts ('load_and_split'). These parts are fed into the summarization chain ('chain.run(docs)'), which processes and condenses the content. Finally, the summarized content is displayed in markdown format directly within the output environment, ensuring that the formatting of the summary remains intact.

# %%
chain = load_summarize_chain(llm, chain_type="map_reduce")

url = "https://arxiv.org/pdf/1706.03762"
loader = PyPDFLoader(url)
docs = loader.load_and_split()
summary = chain.invoke(docs)['output_text']
display_markdown(summary, raw=True)
# Out:
# - The paper presents the Transformer: an encoder–decoder sequence transduction model that removes recurrence and convolution, relying solely on (self-)attention for all intra- and cross-sequence interactions.
# - Core innovations: Scaled Dot-Product Attention (Attention(Q,K,V)=softmax(QK^T/√dk)V), Multi-Head Attention (parallel attention heads with learned projections), and sinusoidal positional encodings to inject order information.
# - Architecture: stacked encoder and decoder blocks (N=6 in the base model) with each sub-layer using residual connections + LayerNorm; each encoder layer has multi-head self-attention + position-wise feed-forward (d_model=512, d_ff=2048); decoder adds masked self-attention and encoder–decoder attention.
# - Computational advantages: self-attention yields O(n^2·d) cost but O(1) sequential steps and O(1) maximum path length between positions, enabling massive parallelism and faster training compared with RNNs (O(n) steps) and many convolutions.
# - Training and regularization: Adam with warmup/decay schedule, dropout, label smoothing, checkpoint averaging, and beam search. Base model trains ~12 hours on 8 P100 GPUs; big model (d_model=1024, 16 heads) trained in ~3.5 days.
# - Results: state-of-the-art on WMT14 English→German (28.4 BLEU, exceeding prior single/ensemble results) and English→French (~41.8 BLEU), with substantially lower FLOPs than comparable models.
# - Ablations: multiple heads and appropriate key/value sizes are important; learned positional embeddings perform similarly to sinusoidal; larger models and dropout improve performance.
# - Generalization and interpretability: strong performance on English constituency parsing (up to 92.7 F1 with semi-supervision); attention heads specialize (e.g., tracking long-distance dependencies, anaphora), aiding analysis.
# - Contributions: first full sequence transduction model based entirely on self-attention, with released code and suggestions for future work (local/restricted attention, broader modalities, reducing autoregressive decoding).

# %% [markdown]
# ## Summarize with Custom Prompt
#
# LangChain also allows the use of custom system prompts to tailor text summarization according to specific requirements, such as summarizing content in a different language. This flexibility is showcased in the provided code, where a custom prompt template instructs the system to write a concise summary in Spanish. The template is set up to include a placeholder for the text that needs summarizing, followed by an instruction in Spanish to produce a summary. This custom prompt is then incorporated into the summarization process by configuring both the 'map_prompt' and 'combine_prompt' parameters of the 'load_summarize_chain' function. The process begins by downloading a PDF from a specified URL using 'PyPDFLoader', splitting the document into sections, and then applying the summarization chain with the custom prompt to generate a summarized output in Spanish. The summarized content is then displayed in markdown format to maintain proper formatting. This example illustrates the adaptability of LangChain in handling complex summarization tasks that include language-specific instructions.

# %%
TEMPLATE = """
Write a concise summary of the information presented. Write the summary in Spanish.

{text}

SUMMARY:"""
PROMPT = PromptTemplate(template=TEMPLATE, input_variables=["text"])

chain = load_summarize_chain(llm, chain_type="map_reduce", map_prompt=PROMPT, combine_prompt=PROMPT)

url = "https://arxiv.org/pdf/1706.03762"
loader = PyPDFLoader(url)
docs = loader.load_and_split()
summary = chain.invoke(docs)['output_text']
display_markdown(summary, raw=True)
# Out:
# El texto presenta Transformer, un modelo seq2seq encoder‑decoder que prescinde de recurrencias y convoluciones y se basa únicamente en mecanismos de atención (auto‑atención multi‑cabeza y atención encoder‑decoder) y capas feed‑forward posicionales, lo que permite alto paralelismo y entrenamiento mucho más rápido. La arquitectura típica usa N=6 encoders y decoders apilados, con conexiones residuales y normalización por capa; dimensiones del modelo base: d_model=512, d_ff=2048, h=8 (d_k=d_v=64). La atención escalada por producto punto Attention(Q,K,V)=softmax((QK^T)/√d_k)V estabiliza gradientes; Multi‑Head proyecta Q,K,V varias veces para atender distintos subespacios. Las codificaciones posicionales sinusoidales (sin/cos) se suman a los embeddings y aportan orden; embeddings posicionales aprendidos rinden de forma similar. La FFN es una MLP por posición: max(0,xW1+b1)W2+b2. Self‑attention tiene coste O(n^2·d) pero permite operaciones mayoritariamente paralelas y caminos de dependencia de longitud O(1), facilitando el aprendizaje de dependencias a largo alcance frente a RNNs y convoluciones. En WMT14, el modelo base logra ~27–28 BLEU en EN→DE/EN→FR y el modelo "big" (d_model=1024, d_ff=4096, h=16) mejora los resultados (SOTA en su momento); se reportan también perplexities y mejoras con modelos mayores. Entrenamiento con Adam (β1=0.9, β2=0.98, ϵ=1e‑9), schedule con warmup_steps=4000 y decaimiento ∝1/√step; batches ≈25k tokens por lado, hardware 8×P100; tiempos aproximados: base ~100k pasos (~12 h), big ~300k pasos (~3.5 días). Regularización: dropout ≈0.1, label smoothing ε_ls=0.1, promediado de checkpoints, sharing de embeddings y pre‑softmax y decodificación por beam search (p. ej. beam=4, α≈0.6). Observaciones: multi‑cabeza mejora capacidad y ofrece cierta interpretabilidad (cabezas especializadas), reducir d_k o usar pocas cabezas perjudica, y limitar la atención a vecindades es una vía para secuencias muy largas. Se muestran buenos resultados también en análisis de constituyentes y visualizaciones de atención; el código está disponible en https://github.com/tensorflow/tensor2tensor.

# %%
from html import escape
from IPython.display import HTML

HTML(f"<pre>{escape(summary)}</pre>")

# print(summary)
# Out:
# <pre>El texto presenta Transformer, un modelo seq2seq encoder‑decoder que prescinde de recurrencias y convoluciones y se basa únicamente en mecanismos de atención (auto‑atención multi‑cabeza y atención encoder‑decoder) y capas feed‑forward posicionales, lo que permite alto paralelismo y entrenamiento mucho más rápido. La arquitectura típica usa N=6 encoders y decoders apilados, con conexiones residuales y normalización por capa; dimensiones del modelo base: d_model=512, d_ff=2048, h=8 (d_k=d_v=64). La atención escalada por producto punto Attention(Q,K,V)=softmax((QK^T)/√d_k)V estabiliza gradientes; Multi‑Head proyecta Q,K,V varias veces para atender distintos subespacios. Las codificaciones posicionales sinusoidales (sin/cos) se suman a los embeddings y aportan orden; embeddings posicionales aprendidos rinden de forma similar. La FFN es una MLP por posición: max(0,xW1+b1)W2+b2. Self‑attention tiene coste O(n^2·d) pero permite operaciones mayoritariamente paralelas y caminos de dependencia de longitud O(1), facilitando el aprendizaje de dependencias a largo alcance frente a RNNs y convoluciones. En WMT14, el modelo base logra ~27–28 BLEU en EN→DE/EN→FR y el modelo &quot;big&quot; (d_model=1024, d_ff=4096, h=16) mejora los resultados (SOTA en su momento); se reportan también perplexities y mejoras con modelos mayores. Entrenamiento con Adam (β1=0.9, β2=0.98, ϵ=1e‑9), schedule con warmup_steps=4000 y decaimiento ∝1/√step; batches ≈25k tokens por lado, hardware 8×P100; tiempos aproximados: base ~100k pasos (~12 h), big ~300k pasos (~3.5 días). Regularización: dropout ≈0.1, label smoothing ε_ls=0.1, promediado de checkpoints, sharing de embeddings y pre‑softmax y decodificación por beam search (p. ej. beam=4, α≈0.6). Observaciones: multi‑cabeza mejora capacidad y ofrece cierta interpretabilidad (cabezas especializadas), reducir d_k o usar pocas cabezas perjudica, y limitar la atención a vecindades es una vía para secuencias muy largas. Se muestran buenos resultados también en análisis de constituyentes y visualizaciones de atención; el código está disponible en https://github.com/tensorflow/tensor2tensor.</pre>

# %% [markdown]
# ## Summarize Multiple PDFs
#
# We will now see how to summarize multiple documents into one. We will summarize the following four papers, each of which is very important to the field of GenAI.
#
# * "[Attention Is All You Need](https://arxiv.org/pdf/1706.03762)" by Ashish Vaswani et al. (2017) - This paper introduced the Transformer architecture, which has become the backbone of most modern natural language processing systems, including text-to-text generative models like GPT and BERT.
# * "[BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding](https://arxiv.org/pdf/1810.04805)" by Jacob Devlin et al. (2018) - BERT (Bidirectional Encoder Representations from Transformers) revolutionized the way contextual information is handled by using a bidirectional training of Transformer models. This methodology significantly improved the performance of models on various NLP tasks.
# * "[Language Models are Few-Shot Learners](https://arxiv.org/pdf/2005.14165)" by Tom B. Brown et al. (2020) - Also known as the GPT-3 paper, it explores the capabilities of very large transformer-based models, demonstrating that scaling up the size of the models improves performance across a broad spectrum of NLP tasks, often requiring little to no task-specific data.
# * "[Exploring the Limits of Transfer Learning with a Unified Text-to-Text Transformer](https://arxiv.org/pdf/1910.10683)" by Colin Raffel et al. (2019) - This paper introduces T5 (Text-to-Text Transfer Transformer), which converts all NLP tasks into a unified text-to-text format, simplifying the application of transfer learning across different tasks.
#
# We use the same process demonstrated to load all these PDF documents and concatenate their summaries into an array.

# %%
urls = [
  "https://arxiv.org/pdf/1706.03762",
  "https://arxiv.org/pdf/1810.04805",
  "https://arxiv.org/pdf/2005.14165",
  "https://arxiv.org/pdf/1910.10683"
]

summaries = []

chain = load_summarize_chain(llm, chain_type="map_reduce")

for url in urls:
  print(f"Reading: {url}")
  loader = PyPDFLoader(url)
  docs = loader.load_and_split()
  chain = load_summarize_chain(llm, chain_type="map_reduce")
  summary = chain.invoke(docs)['output_text']
  summaries.append(summary)
# Out:
# Reading: https://arxiv.org/pdf/1706.03762
# Reading: https://arxiv.org/pdf/1810.04805
# Reading: https://arxiv.org/pdf/2005.14165
# Reading: https://arxiv.org/pdf/1910.10683

# %%
display_markdown(summaries, raw=True)
# Out:
# The paper presents the Transformer, an encoder–decoder sequence‑transduction model that replaces recurrence and convolutions with stacked multi‑head self‑attention and position‑wise feed‑forward layers, supplemented by sinusoidal positional encodings. Key innovations are scaled dot‑product attention and multi‑head attention, which let the model attend to all positions with constant sequential steps and short path lengths for long‑range dependencies, enabling much greater parallelism and faster training than RNNs/CNNs. Architecturally each side uses N=6 layers (decoder adds masked self‑attention and encoder–decoder attention), residual connections, LayerNorm, and shared token embeddings; FFNs are applied position‑wise. Compared to recurrent and convolutional alternatives, self‑attention gives O(n^2·d) per‑layer cost but O(1) sequential operations and O(1) maximum path length, improving efficiency for typical sentence lengths. Empirically the Transformer achieved state‑of‑the‑art single‑model translation: WMT14 En→De BLEU 28.4 and En→Fr ≈41–41.8, training the base model in ~12 hours on 8 P100 GPUs; larger “big” models further improved performance. Ablations show multi‑head attention, head/key dimensions, model size and regularization materially affect quality; learned positional embeddings performed similarly to sinusoidal. The model generalizes to other tasks (e.g., competitive English constituency parsing) and attention heads show interpretable syntactic/semantic roles. Code and configurations were released in Tensor2Tensor.BERT is a pre‑trained, deeply bidirectional Transformer encoder that learns token representations via two pretraining objectives—Masked Language Modeling (MLM: mask 15% of WordPiece tokens with an 80/10/10 [MASK/random/unchanged scheme]) and Next Sentence Prediction (NSP: 50% true next / 50% random sentence pairs). Inputs use [CLS]/[SEP], segment and position embeddings; the same pre‑trained model is fine‑tuned for downstream tasks by adding a small task layer and updating all parameters. Two sizes were released (BERTBASE 110M, BERTLARGE 340M), pretrained on BooksCorpus + English Wikipedia (~1M steps, mostly seq length 128 with final 10% at 512) using large batches, Adam (lr 1e‑4 with warmup/decay), GELU and 0.1 dropout. BERT set new state‑of‑the‑art results across many benchmarks (e.g., GLUE 80.5, MNLI 86.7, SQuAD v1.1 F1 93.2, SQuAD v2.0 F1 83.1), outperforming unidirectional or shallowly combined models. Ablations show bidirectional MLM and NSP materially help, the 80/10/10 masking mix matters, larger models and more pretraining improve transfer, and BERT is effective both for end‑to‑end fine‑tuning and as a feature extractor. Code and pretrained models were released.- Model: GPT-3 is an autoregressive Transformer up to 175B parameters (2048-token context) trained on ≈300B filtered tokens (Common Crawl, WebText, books, Wikipedia).
# - Evaluation paradigm: no fine‑tuning—tasks are solved by zero/one/few‑shot in‑context prompting (natural‑language prompts + examples at test time).
# - Scaling effects: loss and task performance improve smoothly with size; few‑shot gains grow with model scale and the largest models absorb substantial factual knowledge.
# - Empirical performance: GPT‑3 matches or approaches some fine‑tuned/retrieval systems on certain tasks (e.g., TriviaQA, parts of SuperGLUE) but often trails task‑specific SOTA on harder benchmarks (NaturalQuestions, ANLI, RACE, many reading/comprehension and reasoning datasets).
# - Failure modes: poor on complex reasoning, arithmetic and some synthetic tasks; repetition, incoherence and calibration issues remain; sample inefficiency and high inference cost are important practical limits.
# - Data and contamination: extensive preprocessing (quality filtering, deduplication) was applied; a few benchmarks showed training overlap but overall contamination has limited effect on conclusions.
# - Societal impacts: outputs are highly fluent and harder to detect as machine‑written (human detection near chance for 175B), raising misuse risks; models reproduce societal biases (gender, race, religion) and the paper calls for mitigation, multidisciplinary review, and responsible deployment.
# - Compute and reproducibility: authors report training details and estimated compute (~3.1×10^23 FLOPs for 175B) and discuss efficiency, compression and future directions (grounding, multimodality, new objectives).
# - Takeaway: very large pretrained autoregressive models enable powerful in‑context learning that can rival fine‑tuned systems on some tasks, but significant limitations (reasoning, costs, bias, safety) remain and warrant further research and careful deployment.- Paper introduces T5, a unified text‑to‑text framework that casts all NLP tasks as text input → text output, using task prefixes so a single encoder–decoder model, loss, and pipeline handle classification, translation, QA, summarization, etc.
# - Releases C4, a ~750 GB aggressively filtered English corpus from Common Crawl, and shows corpus cleaning, deduplication, size, and domain match materially affect transfer performance.
# - Proposes and empirically validates a span‑corruption denoising pretraining objective (mask contiguous spans, predict concatenated spans with sentinel tokens) with a shared 32k SentencePiece vocabulary; denoising outperforms left‑to‑right LM and deshuffling variants.
# - Trains models at multiple scales (Small → Base → up to T5‑11B) and demonstrates large gains from scale, compute, and longer training; T5‑11B achieves state‑of‑the‑art on many benchmarks (GLUE/SuperGLUE, SQuAD, CNN/DM, WMT).
# - Systematically compares architectures (encoder–decoder, shared weights, reduced depth, decoder‑only, prefix LM) under matched FLOP budgets: full encoder–decoder with denoising performs best; shared weights save parameters with little loss.
# - Studies fine‑tuning and multi‑tasking: full task finetuning yields best results; adapters can be parameter‑efficient if sufficiently large; multi‑task pretraining alone underperforms pretrain→fine‑tune, but combined strategies are effective; sampling/mixing strategy matters.
# - Reports practical tradeoffs: larger models and ensembling improve accuracy but raise inference/fine‑tuning costs; smaller models remain important for constrained settings.
# - Delivers actionable recommendations: use encoder–decoder text‑to‑text models with span‑corruption denoising (≈15% corruption, short spans), prefer shared weights for parameter efficiency, prioritize large/diverse (or domain‑matched) pretraining data, and fine‑tune per task (or use suitably sized adapters).
# - All code, pre-trained models, and the C4 dataset are released to enable reproduction and follow‑on work.

# %% [markdown]
# After obtaining individual summaries of articles, the next step involves combining these summaries into a single, comprehensive overview. The provided code accomplishes this by first merging all the initial summaries into one long string. To manage the potentially large amount of text, it uses the CharacterTextSplitter class from LangChain to split this combined text into manageable chunks. Each chunk maintains a size of 500 characters with an overlap of 100 characters to ensure continuity and context are preserved across chunks. These chunks are then converted into Document objects, each holding a segment of the summarized text. A new summarization chain is loaded using the same 'map_reduce' model to process these document objects. This chain effectively runs across the segmented texts, extracting key information and producing a final, condensed summary of the combined initial summaries. Finally, this ultimate summary is displayed in markdown format to maintain clarity and formatting, providing a clear and succinct synthesis of the original articles' content.

# %%
# from langchain.text_splitter import CharacterTextSplitter
# from langchain.document_loaders import TextLoader
# from langchain.schema.document import Document
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_core.documents import Document

chain = load_summarize_chain(llm, chain_type="map_reduce")

summary_str = " ".join(summaries)
text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=100)
texts = text_splitter.split_text(summary_str)
docs = [Document(page_content=t) for t in texts]
chain = load_summarize_chain(llm, chain_type="map_reduce")
final_summary = chain.invoke(docs)['output_text']
display_markdown(final_summary, raw=True)
# Out:
# Transformers replaced recurrence with multi‑head self‑attention, enabling constant‑step depth, parallelism and strong NMT results. BERT showed the power of deeply bidirectional pretraining (MLM + NSP) for transferable encoders and SOTA fine‑tuning. GPT‑3 scaled autoregressive Transformers to 175B parameters and demonstrated strong in‑context (zero/one/few‑shot) abilities, while exposing limits in reasoning, calibration and biases. T5 framed all tasks as text→text and used span‑corruption denoising on the large C4 corpus, proving encoder–decoder pretraining and scale improve performance. Overall: self‑attention plus large‑scale pretraining and careful task/objective design drive major NLP gains, but practical limits (compute, data quality, biases and reasoning) remain.
