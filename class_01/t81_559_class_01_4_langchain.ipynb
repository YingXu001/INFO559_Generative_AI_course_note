# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_generative_ai/blob/main/t81_559_class_01_4_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-559: Applications of Generative Artificial Intelligence
# **Module 1: Course Overview**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 1 Material
#
# * Part 1.1: Course Overview [[Video]](https://www.youtube.com/watch?v=EqyFvrBHS3A) [[Notebook]](https://www.youtube.com/watch?v=EqyFvrBHS3A)
# * Part 1.2: Generative AI Overview [[Video]](https://www.youtube.com/watch?v=ohmPaSsKhMs) [[Notebook]](t81_559_class_01_2_genai.ipynb)
# * Part 1.3: Introduction to OpenAI [[Video]](https://www.youtube.com/watch?v=C2xyi2Cq-bU) [[Notebook]](t81_559_class_01_3_openai.ipynb)
# * **Part 1.4: Introduction to LangChain** [[Video]](https://www.youtube.com/watch?v=qQI5AhaKxuI) [[Notebook]](t81_559_class_01_4_langchain.ipynb)
# * Part 1.5: Prompt Engineering [[Video]](https://www.youtube.com/watch?v=_Uot1i5sIXo) [[Notebook]](t81_559_class_01_5_prompt_engineering.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running and maps Google Drive if needed.

# %%
import os

try:
    from google.colab import drive, userdata
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# OpenAI Secrets
if COLAB:
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Install needed libraries in CoLab
if COLAB:
    # !pip install langchain langchain_openai
# Out:
# Note: using Google CoLab
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.15)
# Requirement already satisfied: langchain_openai in /usr/local/lib/python3.12/dist-packages (1.1.16)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.3.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (2.31.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (0.14.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.26.0->langchain_openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain_openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain_openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.5.0)

# %% [markdown]
# # Part 1.4: Introduction to LangChain
#
# One of the most intriguing and promising developments in the evolving landscape of language models and artificial intelligence is LangChain. This technology represents a significant leap forward in how we interact with and harness the capabilities of large language models (LLMs). As we delve into the intricacies of LangChain in this chapter, it's important to understand not just the technical underpinnings but also the user experience that makes it so revolutionary.
#
# ## LangChain Chat Conversation Format
#
# To explore LangChain comprehensively, we will adopt a format that has become increasingly familiar and effective in LLMs: the chat conversation interface. This interactive style, reminiscent of how many of us communicate daily, offers a unique and accessible means to illustrate LangChain's capabilities, potential applications, and the nuances of its operation.
#
# We begin by importing the components from the LangChain library to support a chat-style interface to OpenAI. We will use the ChatOpenAI interface for the OpenAI family of LLM models.

# %%
# Conversation Style Inteface

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)
from langchain_openai import ChatOpenAI

# %% [markdown]
# The conversation format consists of arrays of chat entries of the following three types:
#
# * **SystemMessage** - This class designates the system prompt that provides instructions to the AI on the nature of the conversation and hints and guidelines. Generally, there will be only one system message at the beginning of the array.
# * **HumanMessage** - This class designates the chat messages from outside the LLM, typically the human user.
# * **AIMessage** - This class designates the chat messages from the LLM as responses to the HumanMessage messages.
#
# Here we see the chain to ask a simple question.

# %%
messages = [
    SystemMessage(
        content="You are a helpful assistant that concisely and accurately answers questions."
    ),
    HumanMessage(
        content="What is the capital of France?"
    ),
]

# %% [markdown]
# We now submit these messages and retrieve the output from the model. We will use gpt-5-mini, which is good enough for this query. Further, we use a zero temperature; we are simply looking for a factual answer, and creativity is not a goal or concern.

# %%
MODEL = 'gpt-5-mini'

# Initialize the OpenAI LLM with your API key
llm = ChatOpenAI(
  model=MODEL,
  temperature= 0.0,
  n= 1,
  max_tokens= 256)

print("Model response:")
output = llm.invoke(messages)
print(output.content)
print("-----------")
print(output.response_metadata)
# Out:
# Model response:
# The capital of France is Paris.
# -----------
# {'token_usage': {'completion_tokens': 16, 'prompt_tokens': 31, 'total_tokens': 47, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DXWUorKhXrT6pj5V3vqBWHdzfn8v4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}

# %% [markdown]
# The model that LangChain returns to you returns additional metadata. This data shows the token usage, which might be useful for estimating the total cost expected from this query.
#
# We can continue to grow this conversation if we wish. To do so, we added the model's response and another human question. Here, we will ask the model if it was sure about its last response.

# %%
messages.append(output)
messages.append(HumanMessage(content="Are you sure, I think it was renamed for some reason?"))
for message in messages:
    print(f"{type(message).__name__} : {message.content}")
# Out:
# SystemMessage : You are a helpful assistant that concisely and accurately answers questions.
# HumanMessage : What is the capital of France?
# AIMessage : The capital of France is Paris.
# HumanMessage : Are you sure, I think it was renamed for some reason?

# %% [markdown]
# We can submit the conversation array to the model and see its latest response.

# %%
print("Model response:")
output = llm.invoke(messages)
print(output.content)
# Out:
# Model response:

# %% [markdown]
# ## Asking a Single Question
#
# If you wish to ask the model a single question, not as part of a conversation chain, you can pass a string to the model for a response.

# %%
# complete

from langchain_openai import OpenAI, ChatOpenAI

MODEL = 'gpt-5-mini'

# Initialize the OpenAI LLM (Language Learning Model) with your API key
llm = ChatOpenAI(model=MODEL, temperature=0)

# Define the question
question = "What are the five largest cities in the USA by population?"

# Use Langchain to call the OpenAI API
# The method and parameters might differ based on the Langchain version
response = llm.invoke(question)

# Print the response
display(response.content)
# Out:
# 'By population (city proper), the five largest U.S. cities are:\n\n1. New York City, NY  \n2. Los Angeles, CA  \n3. Chicago, IL  \n4. Houston, TX  \n5. Phoenix, AZ\n\nThese rankings are based on recent U.S. Census Bureau population estimates. Want the latest population counts or metro-area rankings too?'

# %% [markdown]
# ## Prompt Templates
#
# LangChain allows you to create chains of operations typically performed as part of an LLM-enabled application. One of these operations is a prompt template, which allows you to insert text into a previously created prompt. In this example, we will create a prompt template that asks the model to create a random blog post title.
#
# ```
# Return only the title of a blog post article title on the topic of {topic} in {language}
# ```
#
# To accomplish this objective, we will use a **PromptTemplate** object.

# %%
# from langchain.prompts import PromptTemplate
from langchain_core.prompts import PromptTemplate

topic = "pets for data scientists"
language = "english"

# Initialize the OpenAI LLM (Language Learning Model) with your API key
# Use higher temperature for greater creativity
llm = ChatOpenAI(model=MODEL, temperature=0.7)

# Define the prompt template
title_template = PromptTemplate(
    input_variables=['topic', 'language'],
    template='Return only the title of a blog post article title on the topic of {topic} in {language}'
)

# Use RunnableSequence for chaining
title_chain = title_template | llm #RunnableSequence(steps=[title_template, llm])

# Invoke the chain with inputs
response = title_chain.invoke({'topic': topic, 'language': language})
print(response.content)
# Out:
# How My Cat Debugged My Model: Pets, Productivity, and the Data Scientist

# %% [markdown]
# ## Create a Simple Sequential Chain
#
# We will now use LangChain to tie multiple LLM calls into a longer chain using the **SimpleSequentialChain** class. We will use two smaller chains to create a title and body text for a blog post. We begin by defining the two prompts we will use to construct this blog post. Also, note that we request that the LLM utilize [markdown](https://en.wikipedia.org/wiki/Markdown) to generate the actual blog post.

# %%
# Create the two prompt templates
title_template = PromptTemplate( input_variables = ['topic'], template = 'Give me a blog post title on {topic} in English' )
article_template = PromptTemplate( input_variables = ['title'], template = 'Write a blog post for {title}, format in markdown.' )

# %% [markdown]
# We will create the first chain to generate the random title. Here, we allow the user to specify the topic. We use a higher temperature to increase the creativity of the title. We also use a simpler model to minimize cost for the relatively simple task of title selection.

# %%
MODEL = 'gpt-5-mini'

# Create a chain to generate a random
llm = ChatOpenAI(model=MODEL, temperature=0.7)
title_chain = title_template | llm

# %% [markdown]
# Next, we compose the actual blog post; we will use a lower temperature to decrease creativity and cause the LLM to stick to factual information and avoid hallucinations. We also use a more complex model to provide a better article.

# %%
MODEL2 = 'gpt-5'

# Create the article chain
llm2 = ChatOpenAI(model=MODEL2, temperature=0.1)
article_chain = article_template | llm2

# %% [markdown]
# Now, we combine these two chains into one. The input to the first chain will be the selected topic. The first chain will then output the title to the second chain, which will, in turn, output the actual article.

# %%
# Create a complete chain to create a new blog post
#complete_chain=SimpleSequentialChain(chains=[title_chain, article_chain], verbose=True)

complete_chain = title_chain | article_chain

# %% [markdown]
# We can now display the final article. In this case, we requested an article on "photography," and displayed the final article's markdown.

# %%
from IPython.display import display_markdown

article = complete_chain.invoke('photography')

# %% [markdown]
# The actual display of the markdown is handled by this code:

# %%
display_markdown(article.content, raw=True)
# Out:
# # Mastering Light: 10 Essential Tips for Stunning Photography
#
# Light is the raw material of every photograph. Master it, and you’ll elevate your images from snapshots to showstoppers. Whether you shoot with a phone or a full-frame camera, these 10 practical tips will help you see, shape, and control light with confidence.
#
# ## 1) Learn to See Light: Quality, Direction, and Color
# - Quality: Soft light (cloudy shade, big windows) wraps gently and flatters skin; hard light (midday sun, bare bulbs) creates crisp shadows and texture.
# - Direction: Front light reveals color; side light adds depth and form; backlight creates glow and drama.
# - Color: Light isn’t just bright or dim—it’s warm/cool. Pay attention to tungsten (warm), shade (cool), and mixed sources.
#
# Pro tip: Close one eye and hold out your hand. Rotate it. Watch how shadows change. That’s light direction at work.
#
# ## 2) Shoot the Right Moments: Golden and Blue Hour
# - Golden hour (around sunrise/sunset): Warm, soft, directional light—great for portraits and landscapes.
# - Blue hour (pre-dawn/post-sunset): Cool, even light—perfect for cityscapes and moody scenes.
# - Midday? Use open shade, backlight with a diffuser, or embrace high-contrast graphics.
#
# ## 3) Shape Light with Simple Tools (or None at All)
# - Reflect: White walls, sidewalks, a piece of foam core, or a 5-in-1 reflector add gentle fill.
# - Diffuse: Thin curtains, a translucent umbrella, or a cheap shower curtain soften harsh sun.
# - Subtract (negative fill): A black card or coat near the face deepens shadows for sculpted contrast.
#
# ## 4) Expose for What Matters
# - Use exposure compensation to protect highlights (+/- button). In backlight, dial in +0.7 to +1.7; in bright scenes, often -0.3 to -1.0 to save detail.
# - Try spot metering on your subject’s face in tricky light.
# - Check the histogram and highlight “blinkies.” Avoid clipping highlights unless you’re going for a silhouette.
#
# ## 5) Balance Color with White Balance and Gels
# - Shoot RAW for flexible color correction.
# - Set custom white balance under mixed light (tungsten + window) to avoid muddy tones.
# - Using flash? Add a CTO gel to match warm indoor bulbs, then correct globally for clean, cohesive color.
#
# ## 6) Control Contrast: Dynamic Range, Fill, and HDR
# - In high-contrast scenes, add fill flash or a reflector to lift shadows.
# - Enable your camera’s highlight-priority or log/flat profile (video) to preserve detail.
# - For static scenes (architecture, landscapes), bracket exposures and merge to HDR naturally—keep it subtle.
#
# ## 7) Make Shadows Your Co‑Author
# - Shadows define shape. Position your subject so shadows carve cheekbones or emphasize texture in street scenes.
# - Try silhouettes: expose for the sky and let your subject fall to black for graphic impact.
# - Explore low key (mostly dark, dramatic) and high key (bright, airy) looks to match mood.
#
# ## 8) Backlight for Glow and Separation
# - Put the sun or a bright window behind your subject to create a rim of light around hair and edges.
# - Use a reflector or spot meter to keep faces properly exposed.
# - Control flare with a lens hood—or embrace it for a dreamy effect. Slightly stop down (f/4–f/8) to sharpen the rim.
#
# ## 9) Make Artificial Light Look Natural
# - Bounce flash off ceilings/walls for large, soft sources; angle to avoid raccoon eyes.
# - Go off-camera (even with a small speedlight) to match the direction of ambient light.
# - Balance flash-to-ambient by setting shutter speed for background mood, then adjust flash power/ISO/aperture for subject.
#
# ## 10) Plan for Light, Not Just Locations
# - Scout at the time you’ll shoot; the same spot looks radically different at noon vs. dusk.
# - Use apps (Sun Seeker, PhotoPills) to track sun angle, golden hour, and moon phases.
# - Watch weather: Overcast is a giant softbox; post-rain brings saturated color and reflective streets.
#
# ---
#
# ### Quick Wins You Can Try Today
# - Move first, then tweak settings: changing your subject’s angle to the light often beats any slider.
# - Use a polarizer to cut glare on water/glass and deepen skies during bright daylight.
# - Keep an ND filter handy for long exposures (silky water, motion blur) without blowing highlights.
# - For cleaner night photos, stabilize (tripod or wall), lower ISO, and expose longer.
#
# ### A Simple 3-Step Workflow On Location
# 1) Identify your key light (sun, window, street lamp). Note quality, direction, and color.
# 2) Decide your intention: crisp contrast, soft portrait, silhouette, or glow.
# 3) Shape and balance: move your subject, add/subtract light (reflector, flash, shade), set exposure/white balance, then refine.
#
# ---
#
# Want this guide tailored to your niche? I can provide variations aimed at:
# - Beginners (simple settings, phone-friendly tricks)
# - Travel (fast light decisions, minimal gear)
# - Portrait (skin tones, flattering modifiers)
# - Street (fast exposure, bold contrast, night light)
#
# Tell me your focus and gear, and I’ll customize a version just for you.
